# %%
doc = [
    "I love machine learning",
    "RNNs are great for sequence data",
    "Integer encoding is useful for text data",
    'Deep learning is fun',
    'Python is a versatile language'
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='<Noting>')

# %%
tokenizer.fit_on_texts(doc)

# %%
tokenizer.word_index
# Out:
# {'<Noting>': 1,
#  'is': 2,
#  'learning': 3,
#  'for': 4,
#  'data': 5,
#  'i': 6,
#  'love': 7,
#  'machine': 8,
#  'rnns': 9,
#  'are': 10,
#  'great': 11,
#  'sequence': 12,
#  'integer': 13,
#  'encoding': 14,
#  'useful': 15,
#  'text': 16,
#  'deep': 17,
#  'fun': 18,
#  'python': 19,
#  'a': 20,
#  'versatile': 21,
#  'language': 22}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('i', 1),
#              ('love', 1),
#              ('machine', 1),
#              ('learning', 2),
#              ('rnns', 1),
#              ('are', 1),
#              ('great', 1),
#              ('for', 2),
#              ('sequence', 1),
#              ('data', 2),
#              ('integer', 1),
#              ('encoding', 1),
#              ('is', 3),
#              ('useful', 1),
#              ('text', 1),
#              ('deep', 1),
#              ('fun', 1),
#              ('python', 1),
#              ('a', 1),
#              ('versatile', 1),
#              ('language', 1)])

# %%
tokenizer.document_count
# Out:
# 5

# %%
sequence = tokenizer.texts_to_sequences(doc)
sequence
# Out:
# [[6, 7, 8, 3],
#  [9, 10, 11, 4, 12, 5],
#  [13, 14, 2, 15, 4, 16, 5],
#  [17, 3, 2, 18],
#  [19, 2, 20, 21, 22]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequence = pad_sequences(sequence, padding='post')
padded_sequence
# Out:
# array([[ 6,  7,  8,  3,  0,  0,  0],
#        [ 9, 10, 11,  4, 12,  5,  0],
#        [13, 14,  2, 15,  4, 16,  5],
#        [17,  3,  2, 18,  0,  0,  0],
#        [19,  2, 20, 21, 22,  0,  0]], dtype=int32)
