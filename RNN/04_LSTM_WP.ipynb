# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
text = '''
Top Deep Learning Interview Questions and Answers for 2026
Deep Learning Interview Questions and Answers
1. What is Deep Learning?
If you are going for a deep learning interview, you definitely know what exactly deep learning is. However, with this question the interviewee expects you to give an in-detail answer, with an example. Deep Learning involves taking large volumes of structured or unstructured data and using complex algorithms to train neural networks. It performs complex operations to extract hidden patterns and features (for instance, distinguishing the image of a cat from that of a dog).
Deep Learning
2. What is a Neural Network?
Neural Networks replicate the way humans learn, inspired by how the neurons in our brains fire, only much simpler.
Neural Network
The most common Neural Networks consist of three network layers:
An input layer
A hidden layer (this is the most important layer where feature extraction takes place, and adjustments are made to train faster and function better)
An output layer
Each sheet contains neurons called “nodes,” performing various operations. Neural Networks are used in deep learning algorithms like CNN, RNN, GAN, etc.
3. What Is a Multi-layer Perceptron(MLP)?
As in Neural Networks, MLPs have an input layer, a hidden layer, and an output layer. It has the same structure as a single layer perceptron with one or more hidden layers. A single layer perceptron can classify only linear separable classes with binary output (0,1), but MLP can classify nonlinear classes.
Except for the input layer, each node in the other layers uses a nonlinear activation function. This means the input layers, the data coming in, and the activation function is based upon all nodes and weights being added together, producing the output. MLP uses a supervised learning method called “backpropagation.” In backpropagation, the neural network calculates the error with the help of cost function. It propagates this error backward from where it came (adjusts the weights to train the model more accurately).
4. What Is Data Normalization, and Why Do We Need It?
The process of standardizing and reforming data is called “Data Normalization.” It’s a pre-processing step to eliminate data redundancy. Often, data comes in, and you get the same information in different formats. In these cases, you should rescale values to fit into a particular range, achieving better convergence.
Become an AI and Machine Learning Expert
With the Professional Certificate in AI and MLExplore ProgramBecome an AI and Machine Learning Expert
5. What is the Boltzmann Machine?
One of the most basic Deep Learning models is a Boltzmann Machine, resembling a simplified version of the Multi-Layer Perceptron. This model features a visible input layer and a hidden layer -- just a two-layer neural net that makes stochastic decisions as to whether a neuron should be on or off. Nodes are connected across layers, but no two nodes of the same layer are connected.
6. What Is the Role of Activation Functions in a Neural Network?
At the most basic level, an activation function decides whether a neuron should be fired or not. It accepts the weighted sum of the inputs and bias as input to any activation function. Step function, Sigmoid, ReLU, Tanh, and Softmax are examples of activation functions.
Role of Activation Functions in a Neural Network
7. What Is the Cost Function?
Also referred to as “loss” or “error,” cost function is a measure to evaluate how good your model’s performance is. It’s used to compute the error of the output layer during backpropagation. We push that error backward through the neural network and use that during the different training functions.
What is the Cost function?
8. What Is Gradient Descent?
Gradient Descent is an optimal algorithm to minimize the cost function or to minimize an error. The aim is to find the local-global minima of a function. This determines the direction the model should take to reduce the error.
Gradient Descent
9. What Do You Understand by Backpropagation?
This is one of the most frequently asked deep learning interview questions. Backpropagation is a technique to improve the performance of the network. It backpropagates the error and updates the weights to reduce the error.
What do you understand by Backpropogation?
10. What Is the Difference Between a Feedforward Neural Network and Recurrent Neural Network?
In this deep learning interview question, the interviewee expects you to give a detailed answer.
A Feedforward Neural Network signals travel in one direction from input to output. There are no feedback loops; the network considers only the current input. It cannot memorize previous inputs (e.g., CNN).
A Recurrent Neural Network’s signals travel in both directions, creating a looped network. It considers the current input with the previously received inputs for generating the output of a layer and can memorize past data due to its internal memory.
Recurrent Neural Network'''

# %%
tokenized = Tokenizer()
tokenized.fit_on_texts([text])

# %%
tokenized.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'is': 4,
#  'to': 5,
#  'of': 6,
#  'layer': 7,
#  'neural': 8,
#  'in': 9,
#  'learning': 10,
#  'network': 11,
#  'what': 12,
#  'function': 13,
#  'deep': 14,
#  'an': 15,
#  'it': 16,
#  'input': 17,
#  'you': 18,
#  'this': 19,
#  'error': 20,
#  'are': 21,
#  'with': 22,
#  'data': 23,
#  'output': 24,
#  'activation': 25,
#  'or': 26,
#  'interview': 27,
#  'for': 28,
#  'networks': 29,
#  'hidden': 30,
#  'most': 31,
#  'layers': 32,
#  'as': 33,
#  'cost': 34,
#  'that': 35,
#  '”': 36,
#  'perceptron': 37,
#  'one': 38,
#  'backpropagation': 39,
#  'should': 40,
#  'machine': 41,
#  'functions': 42,
#  'questions': 43,
#  'train': 44,
#  'from': 45,
#  'by': 46,
#  'only': 47,
#  'called': 48,
#  'mlp': 49,
#  'same': 50,
#  'can': 51,
#  'nodes': 52,
#  'weights': 53,
#  'model': 54,
#  'do': 55,
#  'ai': 56,
#  'inputs': 57,
#  'gradient': 58,
#  'descent': 59,
#  'recurrent': 60,
#  'answers': 61,
#  '1': 62,
#  'question': 63,
#  'interviewee': 64,
#  'expects': 65,
#  'give': 66,
#  'answer': 67,
#  'complex': 68,
#  'algorithms': 69,
#  'operations': 70,
#  'features': 71,
#  'how': 72,
#  'neurons': 73,
#  'where': 74,
#  'better': 75,
#  'each': 76,
#  'used': 77,
#  'cnn': 78,
#  'multi': 79,
#  'single': 80,
#  'more': 81,
#  'classify': 82,
#  'classes': 83,
#  'but': 84,
#  'nonlinear': 85,
#  'uses': 86,
#  'backward': 87,
#  'normalization': 88,
#  'we': 89,
#  'it’s': 90,
#  'step': 91,
#  'different': 92,
#  'expert': 93,
#  'boltzmann': 94,
#  'basic': 95,
#  'two': 96,
#  'whether': 97,
#  'neuron': 98,
#  'be': 99,
#  'connected': 100,
#  'no': 101,
#  'role': 102,
#  'performance': 103,
#  'during': 104,
#  'minimize': 105,
#  'direction': 106,
#  'reduce': 107,
#  'understand': 108,
#  'feedforward': 109,
#  'signals': 110,
#  'travel': 111,
#  'considers': 112,
#  'current': 113,
#  'memorize': 114,
#  'top': 115,
#  '2026': 116,
#  'if': 117,
#  'going': 118,
#  'definitely': 119,
#  'know': 120,
#  'exactly': 121,
#  'however': 122,
#  'detail': 123,
#  'example': 124,
#  'involves': 125,
#  'taking': 126,
#  'large': 127,
#  'volumes': 128,
#  'structured': 129,
#  'unstructured': 130,
#  'using': 131,
#  'performs': 132,
#  'extract': 133,
#  'patterns': 134,
#  'instance': 135,
#  'distinguishing': 136,
#  'image': 137,
#  'cat': 138,
#  'dog': 139,
#  '2': 140,
#  'replicate': 141,
#  'way': 142,
#  'humans': 143,
#  'learn': 144,
#  'inspired': 145,
#  'our': 146,
#  'brains': 147,
#  'fire': 148,
#  'much': 149,
#  'simpler': 150,
#  'common': 151,
#  'consist': 152,
#  'three': 153,
#  'important': 154,
#  'feature': 155,
#  'extraction': 156,
#  'takes': 157,
#  'place': 158,
#  'adjustments': 159,
#  'made': 160,
#  'faster': 161,
#  'sheet': 162,
#  'contains': 163,
#  '“nodes': 164,
#  'performing': 165,
#  'various': 166,
#  'like': 167,
#  'rnn': 168,
#  'gan': 169,
#  'etc': 170,
#  '3': 171,
#  'mlps': 172,
#  'have': 173,
#  'has': 174,
#  'structure': 175,
#  'linear': 176,
#  'separable': 177,
#  'binary': 178,
#  '0': 179,
#  'except': 180,
#  'node': 181,
#  'other': 182,
#  'means': 183,
#  'coming': 184,
#  'based': 185,
#  'upon': 186,
#  'all': 187,
#  'being': 188,
#  'added': 189,
#  'together': 190,
#  'producing': 191,
#  'supervised': 192,
#  'method': 193,
#  '“backpropagation': 194,
#  'calculates': 195,
#  'help': 196,
#  'propagates': 197,
#  'came': 198,
#  'adjusts': 199,
#  'accurately': 200,
#  '4': 201,
#  'why': 202,
#  'need': 203,
#  'process': 204,
#  'standardizing': 205,
#  'reforming': 206,
#  '“data': 207,
#  'pre': 208,
#  'processing': 209,
#  'eliminate': 210,
#  'redundancy': 211,
#  'often': 212,
#  'comes': 213,
#  'get': 214,
#  'information': 215,
#  'formats': 216,
#  'these': 217,
#  'cases': 218,
#  'rescale': 219,
#  'values': 220,
#  'fit': 221,
#  'into': 222,
#  'particular': 223,
#  'range': 224,
#  'achieving': 225,
#  'convergence': 226,
#  'become': 227,
#  'professional': 228,
#  'certificate': 229,
#  'mlexplore': 230,
#  'programbecome': 231,
#  '5': 232,
#  'models': 233,
#  'resembling': 234,
#  'simplified': 235,
#  'version': 236,
#  'visible': 237,
#  'just': 238,
#  'net': 239,
#  'makes': 240,
#  'stochastic': 241,
#  'decisions': 242,
#  'on': 243,
#  'off': 244,
#  'across': 245,
#  '6': 246,
#  'at': 247,
#  'level': 248,
#  'decides': 249,
#  'fired': 250,
#  'not': 251,
#  'accepts': 252,
#  'weighted': 253,
#  'sum': 254,
#  'bias': 255,
#  'any': 256,
#  'sigmoid': 257,
#  'relu': 258,
#  'tanh': 259,
#  'softmax': 260,
#  'examples': 261,
#  '7': 262,
#  'also': 263,
#  'referred': 264,
#  '“loss”': 265,
#  '“error': 266,
#  'measure': 267,
#  'evaluate': 268,
#  'good': 269,
#  'your': 270,
#  'model’s': 271,
#  'compute': 272,
#  'push': 273,
#  'through': 274,
#  'use': 275,
#  'training': 276,
#  '8': 277,
#  'optimal': 278,
#  'algorithm': 279,
#  'aim': 280,
#  'find': 281,
#  'local': 282,
#  'global': 283,
#  'minima': 284,
#  'determines': 285,
#  'take': 286,
#  '9': 287,
#  'frequently': 288,
#  'asked': 289,
#  'technique': 290,
#  'improve': 291,
#  'backpropagates': 292,
#  'updates': 293,
#  'backpropogation': 294,
#  '10': 295,
#  'difference': 296,
#  'between': 297,
#  'detailed': 298,
#  'there': 299,
#  'feedback': 300,
#  'loops': 301,
#  'cannot': 302,
#  'previous': 303,
#  'e': 304,
#  'g': 305,
#  'network’s': 306,
#  'both': 307,
#  'directions': 308,
#  'creating': 309,
#  'looped': 310,
#  'previously': 311,
#  'received': 312,
#  'generating': 313,
#  'past': 314,
#  'due': 315,
#  'its': 316,
#  'internal': 317,
#  'memory': 318}

# %%
input_sequences = []
for sentence in text.split('\n'):
    tokenized_sequence =  tokenized.texts_to_sequences([sentence])[0]
    
    for i in range(1, len(tokenized_sequence)):
        input_sequences.append(tokenized_sequence[:i+1])

# %%
input_sequences
# Out:
# [[115, 14],
#  [115, 14, 10],
#  [115, 14, 10, 27],
#  [115, 14, 10, 27, 43],
#  [115, 14, 10, 27, 43, 3],
#  [115, 14, 10, 27, 43, 3, 61],
#  [115, 14, 10, 27, 43, 3, 61, 28],
#  [115, 14, 10, 27, 43, 3, 61, 28, 116],
#  [14, 10],
#  [14, 10, 27],
#  [14, 10, 27, 43],
#  [14, 10, 27, 43, 3],
#  [14, 10, 27, 43, 3, 61],
#  [62, 12],
#  [62, 12, 4],
#  [62, 12, 4, 14],
#  [62, 12, 4, 14, 10],
#  [117, 18],
#  [117, 18, 21],
#  [117, 18, 21, 118],
#  [117, 18, 21, 118, 28],
#  [117, 18, 21, 118, 28, 2],
#  [117, 18, 21, 118, 28, 2, 14],
#  [117, 18, 21, 118, 28, 2, 14, 10],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120, 12],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120, 12, 121],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120, 12, 121, 14],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120, 12, 121, 14, 10],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120, 12, 121, 14, 10, 4],
#  [117, 18, 21, 118, 28, 2, 14, 10, 27, 18, 119, 120, 12, 121, 14, 10, 4, 122],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2,
#   138],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2,
#   138,
#   45],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2,
#   138,
#   45,
#   35],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2,
#   138,
#   45,
#   35,
#   6],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2,
#   138,
#   45,
#   35,
#   6,
#   2],
#  [117,
#   18,
#   21,
#   118,
#   28,
#   2,
#   14,
#   10,
#   27,
#   18,
#   119,
#   120,
#   12,
#   121,
#   14,
#   10,
#   4,
#   122,
#   22,
#   19,
#   63,
#   1,
#   64,
#   65,
#   18,
#   5,
#   66,
#   15,
#   9,
#   123,
#   67,
#   22,
#   15,
#   124,
#   14,
#   10,
#   125,
#   126,
#   127,
#   128,
#   6,
#   129,
#   26,
#   130,
#   23,
#   3,
#   131,
#   68,
#   69,
#   5,
#   44,
#   8,
#   29,
#   16,
#   132,
#   68,
#   70,
#   5,
#   133,
#   30,
#   134,
#   3,
#   71,
#   28,
#   135,
#   136,
#   1,
#   137,
#   6,
#   2,
#   138,
#   45,
#   35,
#   6,
#   2,
#   139],
#  [14, 10],
#  [140, 12],
#  [140, 12, 4],
#  [140, 12, 4, 2],
#  [140, 12, 4, 2, 8],
#  [140, 12, 4, 2, 8, 11],
#  [8, 29],
#  [8, 29, 141],
#  [8, 29, 141, 1],
#  [8, 29, 141, 1, 142],
#  [8, 29, 141, 1, 142, 143],
#  [8, 29, 141, 1, 142, 143, 144],
#  [8, 29, 141, 1, 142, 143, 144, 145],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73, 9],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73, 9, 146],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73, 9, 146, 147],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73, 9, 146, 147, 148],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73, 9, 146, 147, 148, 47],
#  [8, 29, 141, 1, 142, 143, 144, 145, 46, 72, 1, 73, 9, 146, 147, 148, 47, 149],
#  [8,
#   29,
#   141,
#   1,
#   142,
#   143,
#   144,
#   145,
#   46,
#   72,
#   1,
#   73,
#   9,
#   146,
#   147,
#   148,
#   47,
#   149,
#   150],
#  [8, 11],
#  [1, 31],
#  [1, 31, 151],
#  [1, 31, 151, 8],
#  [1, 31, 151, 8, 29],
#  [1, 31, 151, 8, 29, 152],
#  [1, 31, 151, 8, 29, 152, 6],
#  [1, 31, 151, 8, 29, 152, 6, 153],
#  [1, 31, 151, 8, 29, 152, 6, 153, 11],
#  [1, 31, 151, 8, 29, 152, 6, 153, 11, 32],
#  [15, 17],
#  [15, 17, 7],
#  [2, 30],
#  [2, 30, 7],
#  [2, 30, 7, 19],
#  [2, 30, 7, 19, 4],
#  [2, 30, 7, 19, 4, 1],
#  [2, 30, 7, 19, 4, 1, 31],
#  [2, 30, 7, 19, 4, 1, 31, 154],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157, 158],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157, 158, 3],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157, 158, 3, 159],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157, 158, 3, 159, 21],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157, 158, 3, 159, 21, 160],
#  [2, 30, 7, 19, 4, 1, 31, 154, 7, 74, 155, 156, 157, 158, 3, 159, 21, 160, 5],
#  [2,
#   30,
#   7,
#   19,
#   4,
#   1,
#   31,
#   154,
#   7,
#   74,
#   155,
#   156,
#   157,
#   158,
#   3,
#   159,
#   21,
#   160,
#   5,
#   44],
#  [2,
#   30,
#   7,
#   19,
#   4,
#   1,
#   31,
#   154,
#   7,
#   74,
#   155,
#   156,
#   157,
#   158,
#   3,
#   159,
#   21,
#   160,
#   5,
#   44,
#   161],
#  [2,
#   30,
#   7,
#   19,
#   4,
#   1,
#   31,
#   154,
#   7,
#   74,
#   155,
#   156,
#   157,
#   158,
#   3,
#   159,
#   21,
#   160,
#   5,
#   44,
#   161,
#   3],
#  [2,
#   30,
#   7,
#   19,
#   4,
#   1,
#   31,
#   154,
#   7,
#   74,
#   155,
#   156,
#   157,
#   158,
#   3,
#   159,
#   21,
#   160,
#   5,
#   44,
#   161,
#   3,
#   13],
#  [2,
#   30,
#   7,
#   19,
#   4,
#   1,
#   31,
#   154,
#   7,
#   74,
#   155,
#   156,
#   157,
#   158,
#   3,
#   159,
#   21,
#   160,
#   5,
#   44,
#   161,
#   3,
#   13,
#   75],
#  [15, 24],
#  [15, 24, 7],
#  [76, 162],
#  [76, 162, 163],
#  [76, 162, 163, 73],
#  [76, 162, 163, 73, 48],
#  [76, 162, 163, 73, 48, 164],
#  [76, 162, 163, 73, 48, 164, 36],
#  [76, 162, 163, 73, 48, 164, 36, 165],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29, 21],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29, 21, 77],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29, 21, 77, 9],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29, 21, 77, 9, 14],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29, 21, 77, 9, 14, 10],
#  [76, 162, 163, 73, 48, 164, 36, 165, 166, 70, 8, 29, 21, 77, 9, 14, 10, 69],
#  [76,
#   162,
#   163,
#   73,
#   48,
#   164,
#   36,
#   165,
#   166,
#   70,
#   8,
#   29,
#   21,
#   77,
#   9,
#   14,
#   10,
#   69,
#   167],
#  [76,
#   162,
#   163,
#   73,
#   48,
#   164,
#   36,
#   165,
#   166,
#   70,
#   8,
#   29,
#   21,
#   77,
#   9,
#   14,
#   10,
#   69,
#   167,
#   78],
#  [76,
#   162,
#   163,
#   73,
#   48,
#   164,
#   36,
#   165,
#   166,
#   70,
#   8,
#   29,
#   21,
#   77,
#   9,
#   14,
#   10,
#   69,
#   167,
#   78,
#   168],
#  [76,
#   162,
#   163,
#   73,
#   48,
#   164,
#   36,
#   165,
#   166,
#   70,
#   8,
#   29,
#   21,
#   77,
#   9,
#   14,
#   10,
#   69,
#   167,
#   78,
#   168,
#   169],
#  [76,
#   162,
#   163,
#   73,
#   48,
#   164,
#   36,
#   165,
#   166,
#   70,
#   8,
#   29,
#   21,
#   77,
#   9,
#   14,
#   10,
#   69,
#   167,
#   78,
#   168,
#   169,
#   170],
#  [171, 12],
#  [171, 12, 4],
#  [171, 12, 4, 2],
#  [171, 12, 4, 2, 79],
#  [171, 12, 4, 2, 79, 7],
#  [171, 12, 4, 2, 79, 7, 37],
#  [171, 12, 4, 2, 79, 7, 37, 49],
#  [33, 9],
#  [33, 9, 8],
#  [33, 9, 8, 29],
#  [33, 9, 8, 29, 172],
#  [33, 9, 8, 29, 172, 173],
#  [33, 9, 8, 29, 172, 173, 15],
#  [33, 9, 8, 29, 172, 173, 15, 17],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15, 24],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15, 24, 7],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15, 24, 7, 16],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15, 24, 7, 16, 174],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15, 24, 7, 16, 174, 1],
#  [33, 9, 8, 29, 172, 173, 15, 17, 7, 2, 30, 7, 3, 15, 24, 7, 16, 174, 1, 50],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62,
#   84],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62,
#   84,
#   49],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62,
#   84,
#   49,
#   51],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62,
#   84,
#   49,
#   51,
#   82],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62,
#   84,
#   49,
#   51,
#   82,
#   85],
#  [33,
#   9,
#   8,
#   29,
#   172,
#   173,
#   15,
#   17,
#   7,
#   2,
#   30,
#   7,
#   3,
#   15,
#   24,
#   7,
#   16,
#   174,
#   1,
#   50,
#   175,
#   33,
#   2,
#   80,
#   7,
#   37,
#   22,
#   38,
#   26,
#   81,
#   30,
#   32,
#   2,
#   80,
#   7,
#   37,
#   51,
#   82,
#   47,
#   176,
#   177,
#   83,
#   22,
#   178,
#   24,
#   179,
#   62,
#   84,
#   49,
#   51,
#   82,
#   85,
#   83],
#  [180, 28],
#  [180, 28, 1],
#  [180, 28, 1, 17],
#  [180, 28, 1, 17, 7],
#  [180, 28, 1, 17, 7, 76],
#  [180, 28, 1, 17, 7, 76, 181],
#  [180, 28, 1, 17, 7, 76, 181, 9],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2, 85],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2, 85, 25],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2, 85, 25, 13],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2, 85, 25, 13, 19],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2, 85, 25, 13, 19, 183],
#  [180, 28, 1, 17, 7, 76, 181, 9, 1, 182, 32, 86, 2, 85, 25, 13, 19, 183, 1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45,
#   74],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45,
#   74,
#   16],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45,
#   74,
#   16,
#   198],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45,
#   74,
#   16,
#   198,
#   199],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45,
#   74,
#   16,
#   198,
#   199,
#   1],
#  [180,
#   28,
#   1,
#   17,
#   7,
#   76,
#   181,
#   9,
#   1,
#   182,
#   32,
#   86,
#   2,
#   85,
#   25,
#   13,
#   19,
#   183,
#   1,
#   17,
#   32,
#   1,
#   23,
#   184,
#   9,
#   3,
#   1,
#   25,
#   13,
#   4,
#   185,
#   186,
#   187,
#   52,
#   3,
#   53,
#   188,
#   189,
#   190,
#   191,
#   1,
#   24,
#   49,
#   86,
#   2,
#   192,
#   10,
#   193,
#   48,
#   194,
#   36,
#   9,
#   39,
#   1,
#   8,
#   11,
#   195,
#   1,
#   20,
#   22,
#   1,
#   196,
#   6,
#   34,
#   13,
#   16,
#   197,
#   19,
#   20,
#   87,
#   45,
#   74,
#   16,
#   198,
#   199,
#   1,
# ...
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54,
#   40],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54,
#   40,
#   286],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54,
#   40,
#   286,
#   5],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54,
#   40,
#   286,
#   5,
#   107],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54,
#   40,
#   286,
#   5,
#   107,
#   1],
#  [58,
#   59,
#   4,
#   15,
#   278,
#   279,
#   5,
#   105,
#   1,
#   34,
#   13,
#   26,
#   5,
#   105,
#   15,
#   20,
#   1,
#   280,
#   4,
#   5,
#   281,
#   1,
#   282,
#   283,
#   284,
#   6,
#   2,
#   13,
#   19,
#   285,
#   1,
#   106,
#   1,
#   54,
#   40,
#   286,
#   5,
#   107,
#   1,
#   20],
#  [58, 59],
#  [287, 12],
#  [287, 12, 55],
#  [287, 12, 55, 18],
#  [287, 12, 55, 18, 108],
#  [287, 12, 55, 18, 108, 46],
#  [287, 12, 55, 18, 108, 46, 39],
#  [19, 4],
#  [19, 4, 38],
#  [19, 4, 38, 6],
#  [19, 4, 38, 6, 1],
#  [19, 4, 38, 6, 1, 31],
#  [19, 4, 38, 6, 1, 31, 288],
#  [19, 4, 38, 6, 1, 31, 288, 289],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39, 4],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39, 4, 2],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39, 4, 2, 290],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39, 4, 2, 290, 5],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39, 4, 2, 290, 5, 291],
#  [19, 4, 38, 6, 1, 31, 288, 289, 14, 10, 27, 43, 39, 4, 2, 290, 5, 291, 1],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293,
#   1],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293,
#   1,
#   53],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293,
#   1,
#   53,
#   5],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293,
#   1,
#   53,
#   5,
#   107],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293,
#   1,
#   53,
#   5,
#   107,
#   1],
#  [19,
#   4,
#   38,
#   6,
#   1,
#   31,
#   288,
#   289,
#   14,
#   10,
#   27,
#   43,
#   39,
#   4,
#   2,
#   290,
#   5,
#   291,
#   1,
#   103,
#   6,
#   1,
#   11,
#   16,
#   292,
#   1,
#   20,
#   3,
#   293,
#   1,
#   53,
#   5,
#   107,
#   1,
#   20],
#  [12, 55],
#  [12, 55, 18],
#  [12, 55, 18, 108],
#  [12, 55, 18, 108, 46],
#  [12, 55, 18, 108, 46, 294],
#  [295, 12],
#  [295, 12, 4],
#  [295, 12, 4, 1],
#  [295, 12, 4, 1, 296],
#  [295, 12, 4, 1, 296, 297],
#  [295, 12, 4, 1, 296, 297, 2],
#  [295, 12, 4, 1, 296, 297, 2, 109],
#  [295, 12, 4, 1, 296, 297, 2, 109, 8],
#  [295, 12, 4, 1, 296, 297, 2, 109, 8, 11],
#  [295, 12, 4, 1, 296, 297, 2, 109, 8, 11, 3],
#  [295, 12, 4, 1, 296, 297, 2, 109, 8, 11, 3, 60],
#  [295, 12, 4, 1, 296, 297, 2, 109, 8, 11, 3, 60, 8],
#  [295, 12, 4, 1, 296, 297, 2, 109, 8, 11, 3, 60, 8, 11],
#  [9, 19],
#  [9, 19, 14],
#  [9, 19, 14, 10],
#  [9, 19, 14, 10, 27],
#  [9, 19, 14, 10, 27, 63],
#  [9, 19, 14, 10, 27, 63, 1],
#  [9, 19, 14, 10, 27, 63, 1, 64],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65, 18],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65, 18, 5],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65, 18, 5, 66],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65, 18, 5, 66, 2],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65, 18, 5, 66, 2, 298],
#  [9, 19, 14, 10, 27, 63, 1, 64, 65, 18, 5, 66, 2, 298, 67],
#  [2, 109],
#  [2, 109, 8],
#  [2, 109, 8, 11],
#  [2, 109, 8, 11, 110],
#  [2, 109, 8, 11, 110, 111],
#  [2, 109, 8, 11, 110, 111, 9],
#  [2, 109, 8, 11, 110, 111, 9, 38],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5, 24],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5, 24, 299],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5, 24, 299, 21],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5, 24, 299, 21, 101],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5, 24, 299, 21, 101, 300],
#  [2, 109, 8, 11, 110, 111, 9, 38, 106, 45, 17, 5, 24, 299, 21, 101, 300, 301],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302,
#   114],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302,
#   114,
#   303],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302,
#   114,
#   303,
#   57],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302,
#   114,
#   303,
#   57,
#   304],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302,
#   114,
#   303,
#   57,
#   304,
#   305],
#  [2,
#   109,
#   8,
#   11,
#   110,
#   111,
#   9,
#   38,
#   106,
#   45,
#   17,
#   5,
#   24,
#   299,
#   21,
#   101,
#   300,
#   301,
#   1,
#   11,
#   112,
#   47,
#   1,
#   113,
#   17,
#   16,
#   302,
#   114,
#   303,
#   57,
#   304,
#   305,
#   78],
#  [2, 60],
#  [2, 60, 8],
#  [2, 60, 8, 306],
#  [2, 60, 8, 306, 110],
#  [2, 60, 8, 306, 110, 111],
#  [2, 60, 8, 306, 110, 111, 9],
#  [2, 60, 8, 306, 110, 111, 9, 307],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310, 11],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310, 11, 16],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310, 11, 16, 112],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310, 11, 16, 112, 1],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310, 11, 16, 112, 1, 113],
#  [2, 60, 8, 306, 110, 111, 9, 307, 308, 309, 2, 310, 11, 16, 112, 1, 113, 17],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314,
#   23],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314,
#   23,
#   315],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314,
#   23,
#   315,
#   5],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314,
#   23,
#   315,
#   5,
#   316],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314,
#   23,
#   315,
#   5,
#   316,
#   317],
#  [2,
#   60,
#   8,
#   306,
#   110,
#   111,
#   9,
#   307,
#   308,
#   309,
#   2,
#   310,
#   11,
#   16,
#   112,
#   1,
#   113,
#   17,
#   22,
#   1,
#   311,
#   312,
#   57,
#   28,
#   313,
#   1,
#   24,
#   6,
#   2,
#   7,
#   3,
#   51,
#   114,
#   314,
#   23,
#   315,
#   5,
#   316,
#   317,
#   318],
#  [60, 8],
#  [60, 8, 11]]

# %%
max([len(x) for x in input_sequences])
# Out:
# 83

# %%
max_length = max([len(x) for x in input_sequences])

# %%
padded_sequence_text = pad_sequences(input_sequences, maxlen=max_length, padding='pre')
padded_sequence_text
# Out:
# array([[  0,   0,   0, ...,   0, 115,  14],
#        [  0,   0,   0, ..., 115,  14,  10],
#        [  0,   0,   0, ...,  14,  10,  27],
#        ...,
#        [  0,   0,   0, ..., 316, 317, 318],
#        [  0,   0,   0, ...,   0,  60,   8],
#        [  0,   0,   0, ...,  60,   8,  11]])

# %%
X = padded_sequence_text[:,:-1]
y = padded_sequence_text[:,-1]

# %%
X.shape, y.shape
# Out:
# ((775, 82), (775,))

# %%
y = to_categorical(y, num_classes=len(tokenized.word_index)+1)
y.shape
# Out:
# (775, 319)

# %%
model = Sequential([
    Embedding(input_dim=319, output_dim=64, input_length=82),
    LSTM(180), 
    Dense(319, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=1)
model.summary()
# Out:
# Epoch 1/100
# 25/25 [==============================] - 5s 84ms/step - loss: 5.5657 - accuracy: 0.0490
# Epoch 2/100
# 25/25 [==============================] - 2s 85ms/step - loss: 5.2091 - accuracy: 0.0671
# Epoch 3/100
# 25/25 [==============================] - 2s 84ms/step - loss: 5.1359 - accuracy: 0.0671
# Epoch 4/100
# 25/25 [==============================] - 3s 136ms/step - loss: 5.1018 - accuracy: 0.0671
# Epoch 5/100
# 25/25 [==============================] - 4s 153ms/step - loss: 5.0784 - accuracy: 0.0671
# Epoch 6/100
# 25/25 [==============================] - 4s 145ms/step - loss: 5.0300 - accuracy: 0.0671
# Epoch 7/100
# 25/25 [==============================] - 4s 142ms/step - loss: 4.9567 - accuracy: 0.0710
# Epoch 8/100
# 25/25 [==============================] - 4s 141ms/step - loss: 4.8618 - accuracy: 0.0826
# Epoch 9/100
# 25/25 [==============================] - 4s 148ms/step - loss: 4.7360 - accuracy: 0.0968
# Epoch 10/100
# 25/25 [==============================] - 4s 142ms/step - loss: 4.5746 - accuracy: 0.1071
# Epoch 11/100
# 25/25 [==============================] - 4s 143ms/step - loss: 4.3899 - accuracy: 0.1355
# Epoch 12/100
# 25/25 [==============================] - 4s 148ms/step - loss: 4.1777 - accuracy: 0.1613
# Epoch 13/100
# 25/25 [==============================] - 4s 159ms/step - loss: 3.9566 - accuracy: 0.1897
# Epoch 14/100
# 25/25 [==============================] - 4s 149ms/step - loss: 3.7419 - accuracy: 0.2297
# Epoch 15/100
# 25/25 [==============================] - 4s 154ms/step - loss: 3.5284 - accuracy: 0.2361
# Epoch 16/100
# 25/25 [==============================] - 4s 143ms/step - loss: 3.3006 - accuracy: 0.2826
# Epoch 17/100
# 25/25 [==============================] - 3s 140ms/step - loss: 3.0837 - accuracy: 0.3252
# Epoch 18/100
# 25/25 [==============================] - 3s 136ms/step - loss: 2.8591 - accuracy: 0.3626
# Epoch 19/100
# 25/25 [==============================] - 4s 140ms/step - loss: 2.6473 - accuracy: 0.4142
# Epoch 20/100
# 25/25 [==============================] - 3s 139ms/step - loss: 2.4789 - accuracy: 0.4503
# Epoch 21/100
# 25/25 [==============================] - 3s 138ms/step - loss: 2.2631 - accuracy: 0.4929
# Epoch 22/100
# 25/25 [==============================] - 4s 141ms/step - loss: 2.0620 - accuracy: 0.5419
# Epoch 23/100
# 25/25 [==============================] - 3s 137ms/step - loss: 1.9069 - accuracy: 0.5897
# Epoch 24/100
# 25/25 [==============================] - 3s 138ms/step - loss: 1.7380 - accuracy: 0.6426
# Epoch 25/100
# 25/25 [==============================] - 3s 137ms/step - loss: 1.6037 - accuracy: 0.6800
# Epoch 26/100
# 25/25 [==============================] - 3s 137ms/step - loss: 1.4701 - accuracy: 0.7161
# Epoch 27/100
# 25/25 [==============================] - 3s 137ms/step - loss: 1.3287 - accuracy: 0.7587
# Epoch 28/100
# 25/25 [==============================] - 3s 138ms/step - loss: 1.2200 - accuracy: 0.7987
# Epoch 29/100
# 25/25 [==============================] - 3s 137ms/step - loss: 1.1184 - accuracy: 0.8284
# Epoch 30/100
# 25/25 [==============================] - 3s 135ms/step - loss: 1.0236 - accuracy: 0.8529
# Epoch 31/100
# 25/25 [==============================] - 4s 150ms/step - loss: 0.9407 - accuracy: 0.8774
# Epoch 32/100
# 25/25 [==============================] - 3s 135ms/step - loss: 0.8593 - accuracy: 0.9084
# Epoch 33/100
# 25/25 [==============================] - 4s 140ms/step - loss: 0.7933 - accuracy: 0.9187
# Epoch 34/100
# 25/25 [==============================] - 3s 136ms/step - loss: 0.7291 - accuracy: 0.9394
# Epoch 35/100
# 25/25 [==============================] - 3s 136ms/step - loss: 0.6775 - accuracy: 0.9406
# Epoch 36/100
# 25/25 [==============================] - 3s 137ms/step - loss: 0.6218 - accuracy: 0.9432
# Epoch 37/100
# 25/25 [==============================] - 4s 142ms/step - loss: 0.5725 - accuracy: 0.9523
# Epoch 38/100
# 25/25 [==============================] - 4s 141ms/step - loss: 0.5309 - accuracy: 0.9561
# Epoch 39/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.4985 - accuracy: 0.9626
# Epoch 40/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.4632 - accuracy: 0.9613
# Epoch 41/100
# 25/25 [==============================] - 4s 146ms/step - loss: 0.4310 - accuracy: 0.9613
# Epoch 42/100
# 25/25 [==============================] - 3s 137ms/step - loss: 0.3963 - accuracy: 0.9677
# Epoch 43/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.3721 - accuracy: 0.9665
# Epoch 44/100
# 25/25 [==============================] - 3s 139ms/step - loss: 0.3552 - accuracy: 0.9716
# Epoch 45/100
# 25/25 [==============================] - 3s 135ms/step - loss: 0.3368 - accuracy: 0.9690
# Epoch 46/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.3134 - accuracy: 0.9755
# Epoch 47/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.2960 - accuracy: 0.9703
# Epoch 48/100
# 25/25 [==============================] - 3s 134ms/step - loss: 0.2776 - accuracy: 0.9742
# Epoch 49/100
# 25/25 [==============================] - 4s 140ms/step - loss: 0.2620 - accuracy: 0.9716
# Epoch 50/100
# 25/25 [==============================] - 3s 137ms/step - loss: 0.2466 - accuracy: 0.9794
# Epoch 51/100
# 25/25 [==============================] - 3s 135ms/step - loss: 0.2361 - accuracy: 0.9768
# Epoch 52/100
# 25/25 [==============================] - 3s 134ms/step - loss: 0.2274 - accuracy: 0.9742
# Epoch 53/100
# 25/25 [==============================] - 3s 134ms/step - loss: 0.2102 - accuracy: 0.9819
# Epoch 54/100
# 25/25 [==============================] - 3s 140ms/step - loss: 0.2006 - accuracy: 0.9819
# Epoch 55/100
# 25/25 [==============================] - 3s 134ms/step - loss: 0.1975 - accuracy: 0.9794
# Epoch 56/100
# 25/25 [==============================] - 3s 134ms/step - loss: 0.1836 - accuracy: 0.9819
# Epoch 57/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1752 - accuracy: 0.9832
# Epoch 58/100
# 25/25 [==============================] - 4s 147ms/step - loss: 0.1687 - accuracy: 0.9832
# Epoch 59/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.1616 - accuracy: 0.9806
# Epoch 60/100
# 25/25 [==============================] - 3s 135ms/step - loss: 0.1557 - accuracy: 0.9806
# Epoch 61/100
# 25/25 [==============================] - 3s 135ms/step - loss: 0.1484 - accuracy: 0.9858
# Epoch 62/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.1439 - accuracy: 0.9819
# Epoch 63/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1379 - accuracy: 0.9845
# Epoch 64/100
# 25/25 [==============================] - 3s 139ms/step - loss: 0.1337 - accuracy: 0.9845
# Epoch 65/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1273 - accuracy: 0.9858
# Epoch 66/100
# 25/25 [==============================] - 4s 145ms/step - loss: 0.1220 - accuracy: 0.9845
# Epoch 67/100
# 25/25 [==============================] - 5s 198ms/step - loss: 0.1188 - accuracy: 0.9858
# Epoch 68/100
# 25/25 [==============================] - 4s 156ms/step - loss: 0.1122 - accuracy: 0.9871
# Epoch 69/100
# 25/25 [==============================] - 4s 158ms/step - loss: 0.1122 - accuracy: 0.9845
# Epoch 70/100
# 25/25 [==============================] - 4s 157ms/step - loss: 0.1059 - accuracy: 0.9845
# Epoch 71/100
# 25/25 [==============================] - 4s 149ms/step - loss: 0.1019 - accuracy: 0.9845
# Epoch 72/100
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0989 - accuracy: 0.9858
# Epoch 73/100
# 25/25 [==============================] - 3s 136ms/step - loss: 0.0956 - accuracy: 0.9871
# Epoch 74/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.0912 - accuracy: 0.9884
# Epoch 75/100
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0894 - accuracy: 0.9871
# Epoch 76/100
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0866 - accuracy: 0.9884
# Epoch 77/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.0839 - accuracy: 0.9884
# Epoch 78/100
# 25/25 [==============================] - 4s 141ms/step - loss: 0.0806 - accuracy: 0.9897
# Epoch 79/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0784 - accuracy: 0.9884
# Epoch 80/100
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0779 - accuracy: 0.9871
# Epoch 81/100
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0733 - accuracy: 0.9897
# Epoch 82/100
# 25/25 [==============================] - 5s 190ms/step - loss: 0.0714 - accuracy: 0.9884
# Epoch 83/100
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0697 - accuracy: 0.9858
# Epoch 84/100
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0685 - accuracy: 0.9871
# Epoch 85/100
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0664 - accuracy: 0.9897
# Epoch 86/100
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0652 - accuracy: 0.9897
# Epoch 87/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0638 - accuracy: 0.9871
# Epoch 88/100
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0633 - accuracy: 0.9910
# Epoch 89/100
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0618 - accuracy: 0.9871
# Epoch 90/100
# 25/25 [==============================] - 4s 158ms/step - loss: 0.0587 - accuracy: 0.9884
# Epoch 91/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.0577 - accuracy: 0.9858
# Epoch 92/100
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0560 - accuracy: 0.9884
# Epoch 93/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.0580 - accuracy: 0.9858
# Epoch 94/100
# 25/25 [==============================] - 4s 159ms/step - loss: 0.0560 - accuracy: 0.9884
# Epoch 95/100
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0526 - accuracy: 0.9910
# Epoch 96/100
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0516 - accuracy: 0.9858
# Epoch 97/100
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0503 - accuracy: 0.9897
# Epoch 98/100
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0526 - accuracy: 0.9897
# Epoch 99/100
# 25/25 [==============================] - 4s 157ms/step - loss: 0.0498 - accuracy: 0.9897
# Epoch 100/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0467 - accuracy: 0.9884
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 82, 64)            20416
#
#  lstm_7 (LSTM)               (None, 180)               176400
#
#  dense_4 (Dense)             (None, 319)               57739
#
# =================================================================
# Total params: 254,555
# Trainable params: 254,555
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
import numpy as np
text = "Neural Networks replicate"

for i in range(10):
# tokenize
    token_text = tokenized.texts_to_sequences([text])[0]
# padding
    padded_token_text = pad_sequences([token_text], maxlen=82, padding='pre')
# predict
    pos = np.argmax(model.predict(padded_token_text)) + 1


    for word,index in tokenized.word_index.items():
        if index == pos:
            text = text + " " + word
            print(text)
            time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Neural Networks replicate a
# 1/1 [==============================] - 0s 42ms/step
# Neural Networks replicate a humans
# 1/1 [==============================] - 0s 46ms/step
# Neural Networks replicate a humans inspired
# 1/1 [==============================] - 0s 53ms/step
# Neural Networks replicate a humans inspired only
# 1/1 [==============================] - 0s 42ms/step
# Neural Networks replicate a humans inspired only a
# 1/1 [==============================] - 0s 91ms/step
# Neural Networks replicate a humans inspired only a there
# 1/1 [==============================] - 0s 42ms/step
# Neural Networks replicate a humans inspired only a there with
# 1/1 [==============================] - 0s 54ms/step
# Neural Networks replicate a humans inspired only a there with a
# 1/1 [==============================] - 0s 63ms/step
# Neural Networks replicate a humans inspired only a there with a there
# 1/1 [==============================] - 0s 67ms/step
# Neural Networks replicate a humans inspired only a there with a there with

# %%
Neural Networks replicate the way humans learn, inspired by how the neurons in our brains fire, only much
